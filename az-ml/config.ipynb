# %% [markdown]
# ### load env variables

# %%
import os
from dotenv import load_dotenv

load_dotenv()

subscription=os.getenv("SUBSCRIPTION")
resource_group=os.getenv("RESOURCE_GROUP")
ws_name=os.getenv("WS_NAME")
print(f"Subscription: {subscription}")
print(f"Resource Group: {resource_group}")  
print(f"Workspace Name: {ws_name}")
# Out:
# Subscription: 784e6c68-d702-4a8b-a678-2e0f2f36deab
# Resource Group: az-ml-chris
# Workspace Name: AZ-ML-Chris

# %% [markdown]
# ### Create Handle to the workspace

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential

# authenticate
try:
    credential = DefaultAzureCredential()
    credential.get_token("https://management.azure.com/.default")
except Exception:
    credential = InteractiveBrowserCredential()

SUBSCRIPTION = os.getenv("SUBSCRIPTION")
RESOURCE_GROUP = os.getenv("RESOURCE_GROUP")
WS_NAME = os.getenv("WS_NAME")
# Get a handle to the workspace
ml_client = MLClient(
    credential=credential,
    subscription_id=SUBSCRIPTION,
    resource_group_name=RESOURCE_GROUP,
    workspace_name=WS_NAME,
)
# Out:
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# GenAI tracing is not enabled. Set environment variable AZURE_EXPERIMENTAL_ENABLE_GENAI_TRACING=true to enable this experimental feature.

# %% [markdown]
# ### Verify that the handle works correctly

# %%
# Verify that the handle works correctly.
# If you ge an error here, modify your SUBSCRIPTION, RESOURCE_GROUP, and WS_NAME in the previous cell.
ws = ml_client.workspaces.get(WS_NAME)
print(ws.location, ":", ws.resource_group)
# Out:
# eastus2 : az-ml-chris

# %% [markdown]
# ### List all the environments

# %%
envs = ml_client.environments.list()
for env in envs:
    print(env.name)
# Out:
# AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu

# %% [markdown]
# ### Get the details of a specific environment

# %%
envs = ml_client.environments.list()
for env in envs:
    print(env.name)
    env = ml_client.environments.get(name=env.name, version="1")
    print(env)
# Out:
# AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu
# creation_context:
#   created_at: '2023-01-24T03:13:48.129117+00:00'
#   created_by: Microsoft
#   created_by_type: User
#   last_modified_at: '2023-01-24T03:13:48.129117+00:00'
#   last_modified_by: Microsoft
#   last_modified_by_type: User
# description: Recommended environment for Deep Learning in public preview with PyTorch
#   on Azure containing the Azure ML SDK with the latest compatible versions of Ubuntu,
#   Python, PyTorch, CUDA\RocM, combined with optimizers like ORT Training,+DeepSpeed+MSCCL+ORT
#   MoE and more.
# id: azureml:/subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourceGroups/az-ml-chris/providers/Microsoft.MachineLearningServices/workspaces/AZ-ML-Chris/environments/AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu/versions/1
# name: AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu
# os_type: linux
# tags:
#   GPU: Cuda11
#   OS: Ubuntu20.04
#   PyTorch: 1.13.0
#   Training: ''
# version: '1'

# %% [markdown]
# ### Get Environment

# %%
# Get an curated Environment
environment = ml_client.environments.get("AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu", "1")
print (environment)
# Out:
# creation_context:
#   created_at: '2023-01-24T03:13:48.129117+00:00'
#   created_by: Microsoft
#   created_by_type: User
#   last_modified_at: '2023-01-24T03:13:48.129117+00:00'
#   last_modified_by: Microsoft
#   last_modified_by_type: User
# description: Recommended environment for Deep Learning in public preview with PyTorch
#   on Azure containing the Azure ML SDK with the latest compatible versions of Ubuntu,
#   Python, PyTorch, CUDA\RocM, combined with optimizers like ORT Training,+DeepSpeed+MSCCL+ORT
#   MoE and more.
# id: azureml:/subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourceGroups/az-ml-chris/providers/Microsoft.MachineLearningServices/workspaces/AZ-ML-Chris/environments/AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu/versions/1
# name: AzureML-ACPT-pytorch-1.13-py38-cuda11.7-gpu
# os_type: linux
# tags:
#   GPU: Cuda11
#   OS: Ubuntu20.04
#   PyTorch: 1.13.0
#   Training: ''
# version: '1'
