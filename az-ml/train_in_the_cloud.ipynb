# %% [markdown]
# ### Connect to the workspace

# %%
#import required libraries
import os
from dotenv import load_dotenv

load_dotenv()
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential

#Enter details of your Azure Machine Learning workspace
subscription_id = os.getenv("SUBSCRIPTION")
resource_group = os.getenv("RESOURCE_GROUP")
workspace = os.getenv("WS_NAME")


#connect to the workspace
ml_client = MLClient(DefaultAzureCredential(), subscription_id, resource_group, workspace)
# Out:
# Overriding of current MeterProvider is not allowed
# Overriding of current TracerProvider is not allowed
# Overriding of current LoggerProvider is not allowed
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# Attempting to instrument while already instrumented
# GenAI tracing is not enabled. Set environment variable AZURE_EXPERIMENTAL_ENABLE_GENAI_TRACING=true to enable this experimental feature.
# c:\develop\open-source\AILabs\az-ml

# %% [markdown]
# ### Create/Get a compute resource for training

# %%
from azure.ai.ml.entities import AmlCompute

# specify aml compute name.
cpu_compute_target = "baoqger1"

ml_client.compute.get(cpu_compute_target)
# Out:
# ComputeInstance({'state': 'Stopped', 'last_operation': {'operation_name': 'Stop', 'operation_time': '2026-05-10T15:53:56.489Z', 'operation_status': 'Succeeded', 'operation_trigger': 'IdleShutdown'}, 'os_image_metadata': <azure.ai.ml.entities._compute._image_metadata.ImageMetadata object at 0x000001FC91DC7140>, 'services': [{'display_name': 'Jupyter', 'endpoint_uri': 'https://baoqger1.eastus2.instances.azureml.ms/tree/'}, {'display_name': 'Jupyter Lab', 'endpoint_uri': 'https://baoqger1.eastus2.instances.azureml.ms/lab'}], 'type': 'computeinstance', 'created_on': '2026-04-12T12:16:27.651440+0000', 'provisioning_state': 'Succeeded', 'provisioning_errors': None, 'name': 'baoqger1', 'description': None, 'tags': None, 'properties': {}, 'print_as_yaml': False, 'id': '/subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourceGroups/az-ml-chris/providers/Microsoft.MachineLearningServices/workspaces/AZ-ML-Chris/computes/baoqger1', 'Resource__source_path': '', 'base_path': 'c:\\develop\\open-source\\AILabs\\az-ml', 'creation_context': None, 'serialize': <msrest.serialization.Serializer object at 0x000001FC97DA8800>, 'resource_id': None, 'location': 'eastus2', 'size': 'Standard_DS11_v2', 'ssh_public_access_enabled': False, 'create_on_behalf_of': None, 'network_settings': <azure.ai.ml.entities._compute.compute.NetworkSettings object at 0x000001FC96D5C140>, 'ssh_settings': <azure.ai.ml.entities._compute.compute_instance.ComputeInstanceSshSettings object at 0x000001FC951AD160>, 'schedules': None, 'identity': None, 'idle_time_before_shutdown': 'PT60M', 'idle_time_before_shutdown_minutes': 60, 'setup_scripts': None, 'enable_node_public_ip': True, 'enable_sso': True, 'enable_root_access': True, 'release_quota_on_stop': False, 'enable_os_patching': False, 'custom_applications': None, 'subnet': None})

# %% [markdown]
# ### Submit the training job

# %%
from azure.ai.ml import command, Input

# define the command
command_job = command(
    code="./iris/src",
    command="python main.py --iris-csv ${{inputs.iris_csv}} --learning-rate ${{inputs.learning_rate}} --boosting ${{inputs.boosting}}",
    environment="AzureML-lightgbm-3.2-ubuntu18.04-py37-cpu@latest",
    inputs={
        "iris_csv": Input(
            type="uri_file",
            path="https://azuremlexamples.blob.core.windows.net/datasets/iris.csv",
        ),
        "learning_rate": 0.9,
        "boosting": "gbdt",
    },
    compute=cpu_compute_target,
)

# %%
# submit the command
returned_job = ml_client.jobs.create_or_update(command_job)
# get a URL for the status of the job
returned_job.studio_url
# Out:
# Uploading src (0.0 MBs): 100%|##########| 2934/2934 [00:00<00:00, 14613.76it/s]
# 'https://ml.azure.com/runs/loyal_soca_wx1mvm13qy?wsid=/subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourcegroups/az-ml-chris/workspaces/AZ-ML-Chris&tid=293882e2-ff46-4747-b46a-a84ca8e98fa0'
