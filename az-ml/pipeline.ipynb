# %%
import os
from dotenv import load_dotenv

load_dotenv()

subscription=os.getenv("SUBSCRIPTION")
resource_group=os.getenv("RESOURCE_GROUP")
ws_name=os.getenv("WS_NAME")
print(f"Subscription: {subscription}")
print(f"Resource Group: {resource_group}")  
print(f"Workspace Name: {ws_name}")
# Out:
# Subscription: 784e6c68-d702-4a8b-a678-2e0f2f36deab
# Resource Group: az-ml-chris
# Workspace Name: AZ-ML-Chris

# %%
from azure.ai.ml import MLClient
from azure.identity import DefaultAzureCredential, InteractiveBrowserCredential

# authenticate
try:
    credential = DefaultAzureCredential()
    credential.get_token("https://management.azure.com/.default")
except Exception:
    credential = InteractiveBrowserCredential()

SUBSCRIPTION = os.getenv("SUBSCRIPTION")
RESOURCE_GROUP = os.getenv("RESOURCE_GROUP")
WS_NAME = os.getenv("WS_NAME")
# Get a handle to the workspace
ml_client = MLClient(
    credential=credential,
    subscription_id=SUBSCRIPTION,
    resource_group_name=RESOURCE_GROUP,
    workspace_name=WS_NAME,
)
# Out:
# GenAI tracing is not enabled. Set environment variable AZURE_EXPERIMENTAL_ENABLE_GENAI_TRACING=true to enable this experimental feature.
# Class DeploymentTemplateOperations: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
cpu_compute_target = "basic-example"
print(ml_client.compute.get(cpu_compute_target))
# Out:
# enable_node_public_ip: true
# id: /subscriptions/784e6c68-d702-4a8b-a678-2e0f2f36deab/resourceGroups/az-ml-chris/providers/Microsoft.MachineLearningServices/workspaces/AZ-ML-Chris/computes/basic-example
# idle_time_before_scale_down: 120
# location: westus
# max_instances: 2
# min_instances: 0
# name: basic-example
# network_settings: {}
# provisioning_state: Succeeded
# size: STANDARD_DS3_v2
# ssh_public_access_enabled: true
# tier: dedicated
# type: amlcompute
