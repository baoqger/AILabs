# %%
from evaldashscope import eval_dashscope

eval_dashscope()
# Out:
# Evaluating: 100%|██████████| 3/3 [00:23<00:00,  7.92s/it]
#   user_input                                           response  reference  \
# 0  张伟是哪个部门的？  根据提供的信息，没有提到张伟所在的部门。如果您能提供更多关于张伟的信息，我可能能够帮助您找到答案。  张伟是教研部的成员
# 1  张伟是哪个部门的？                                           张伟是人事部门的  张伟是教研部的成员
# 2  张伟是哪个部门的？                                            张伟是教研部的  张伟是教研部的成员
#
#    answer_correctness
# 0            0.175216
# 1            0.193998
# 2            0.994618

# %%
from eval import eval_azure_openai

eval_azure_openai()
