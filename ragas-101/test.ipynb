# %%
from evaldashscope import eval_dashscope

eval_dashscope()
# Out:
# Evaluating: 100%|██████████| 1/1 [00:19<00:00, 19.35s/it]
#                                           user_input  \
# 0  What is depth match? Please directly answer th...
#
#                                             response  \
# 0  Depth matching is the process of aligning two ...
#
#                                            reference  answer_correctness
# 0  Depth matching is the process of aligning two ...                 1.0

# %%
from eval import eval_azure_openai

eval_azure_openai()
# Out:
# Evaluating: 100%|██████████| 1/1 [00:15<00:00, 15.01s/it]
#                                           user_input  \
# 0  What is depth match? Please directly answer th...
#
#                                             response  \
# 0  Depth matching is the process of aligning two ...
#
#                                            reference  answer_correctness
# 0  Depth matching is the process of aligning two ...                 1.0

# %%
question = "What is depth match? Please directly answer the question do not show any reference"
answer = "Depth matching is the process of aligning two well logs by adjusting the depths of one log (the target) so that its measured features correspond to those of the other log (the reference). "
ground_truth = "Depth matching is the process of aligning two well logs by adjusting the depths of one log (the target) so that its measured features correspond to those of the other log (the reference). "

from eval import evaluate_result

evaluate_result(question, answer, ground_truth)
# Out:
# Evaluating: 100%|██████████| 1/1 [00:14<00:00, 14.45s/it]
#                                           user_input  \
# 0  What is depth match? Please directly answer th...
#
#                                             response  \
# 0  Depth matching is the process of aligning two ...
#
#                                            reference  answer_correctness
# 0  Depth matching is the process of aligning two ...                 1.0
